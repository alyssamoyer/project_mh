# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
# %matplotlib notebook


#Load tables created from the data cleaning script as datadrames
mh_adolescent_trends = pd.read_csv('Output/mh_adolescent_trends.csv')
mh_language_trends = pd.read_csv('Output/mh_language_trends.csv')
suicide_rate_service = pd.read_csv('Output/suicide_rate_service.csv')
suicide_rate_payment = pd.read_csv('Output/suicide_rate_payment.csv')
mh_payassist_trends = pd.read_csv('Output/mh_payassist_trends.csv')
mh_lgbt_trends = pd.read_csv('Output/mh_lgbt_trends.csv')
mh_suicide_2017 = pd.read_csv('Output/mh_suicide_2017.csv')
mh_suicide_programs = pd.read_csv('Output/mh_suicide_trends.csv')
mh_suicide_death = pd.read_csv('Output/mh_suicide_all.csv')
mh_cosubstance_programs = pd.read_csv('Output/mh_substance_trends.csv')
mh_veteran_programs = pd.read_csv('Output/mh_verteran_trends.csv')
mh_housing_programs = pd.read_csv('Output/mh_housing_trends.csv')
mh_education_programs = pd.read_csv('Output/mh_education_trends.csv')

# %%
#Loop through list of states in order of lgby trends. Create a list of colors. Blue for democrat, red for republican.
party = []
index_count = 0
for rows in mh_lgbt_trends.iterrows(): 
    if  mh_lgbt_trends.loc[index_count, 'Party']== 'D':
        party.append('royalblue')
    elif mh_lgbt_trends.loc[index_count, 'Party']== 'R':
        party.append('firebrick')
    else:
        party.append('k') 
    index_count = index_count + 1
    
x_ticks = [i for i, _ in enumerate(mh_lgbt_trends['state'])]

plt.bar(x_ticks, mh_lgbt_trends['2016'], .6, color=party)


plt.ylabel("% of MH Facilities with LGBT Program")
plt.title("U.S. Mental Health Facilities with LGBT programs in 2016 by State and Party Affiliation", wrap = True)

plt.xticks(x_ticks, mh_lgbt_trends['state'], rotation = 90)
plt.tight_layout()
plt.style.use('seaborn')

#Create legend for party affiliation
red_patch = mpatches.Patch(color='firebrick', label='Republican')
blue_patch = mpatches.Patch(color='royalblue', label='Democrat')
plt.legend(handles=[red_patch, blue_patch])

plt.savefig("Images/lgbt_program.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
party
# Out:
# ['r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'b',
#  'k',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'r',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'b',
#  'k',
#  'b',
#  'k',
#  'r',
#  'r',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'b',
#  'k',
#  'b',
#  'k',
#  'r',
#  'b',
#  'k',
#  'b',
#  'k',
#  'b',
#  'k',
#  'r',
#  'b',
#  'k',
#  'r',
#  'r',
#  'r',
#  'b',
#  'k',
#  'b',
#  'k',
#  'k',
#  'b',
#  'k',
#  'b',
#  'k',
#  'b',
#  'k',
#  'b',
#  'k']

# %%
lang_plot = mh_lgbt_trends.sort_values('2018', ascending=True).plot(kind="bar", x = "state", y = "2018")
lang_plot.plot(figsize=(8, 6))
plt.title('% of Mental Health Facilities Offering LGBT Programs by State')
plt.xlabel('State')
plt.ylabel( '% Of MH Facilities Offering LGBT Programs')
plt.tight_layout()
plt.savefig("Images/lgbt_programs.png")
plt.show()

colors = []
index_count = 0
for rows in mh_lgbt_trends.iterrows(): 
    if  mh_lgbt_trends.loc[index_count, 'Party']== 'D':
        colors.append('b')
    else:
        colors.append('r')
    index_count = index_count + 1
colors

fig = plt.figure()
ax = fig.add_subplot(111)

N = 5
ind = np.arange(N)
width = 0.5
vals = [1,2,3,4,5]
colors = ['r','b','b','b','b']
ax.barh(ind, vals, width, color=colors)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ['r',
#  'r',
#  'r',
#  'r',
#  'b',
#  'b',
#  'b',
#  'r',
#  'r',
#  'b',
#  'r',
#  'b',
#  'r',
#  'b',
#  'b',
#  'r',
#  'r',
#  'b',
#  'b',
#  'r',
#  'b',
#  'r',
#  'b',
#  'b',
#  'r',
#  'r',
#  'b',
#  'b',
#  'b',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'b',
#  'r']

# %%
x = np.arange(len(mh_lgbt_trends))
tick_locations = [value+0.4 for value in x]

fig, ax = plt.subplots()
width  = .4
rects1 = ax.bar(x - width/2, mh_lgbt_trends.sort_values('2018', ascending=True)['2018'], width, label='2018')
rects2 = ax.bar(x + width/2, mh_lgbt_trends.sort_values('2018', ascending=True)['2017'], width, label='2015')

ax.set_xticks(x)
ax.set_xticklabels(mh_lgbt_trends.sort_values('2018', ascending=True)['state'], rotation=50)

ax.legend()
#ax.xticks(np.arange(12), mh_language_trends['2018'], rotation=20)
#ax.set(tick_locations, x, rotation="vertical")))

plt.tight_layout()
plt.show()
#ax.xticks(np.arange(12), mh_language_trends['2018'], rotation=20)
#ax.set(tick_locations, x, rotation="vertical")

# %%
#suicide_rate_service_plot = suicide_rate_service.plot(kind="scatter", x = "RATE", y = "2017", s=26, edgecolors='black')

for i,type in enumerate(mh_lgbt_trends['state']):
    x = mh_lgbt_trends['state'][i]
    y = suicide_rate_service['2018'][i]
    if mh_lgbt_trends['Party'][i] == 'D':
        ax.bar(x, y, color='blue')
    if mh_lgbt_trends['Party'][i] == 'R':
        ax.bar(x, y, color='red')
    #plt.text(x+0.3, y+0.3, type, fontsize=5, wrap=True)


plt.show()

# %%
#suicide_rate_service_plot = suicide_rate_service.plot(kind="scatter", x = "RATE", y = "2017", s=26, edgecolors='black')

for i,type in enumerate(suicide_rate_service['state']):
    x = suicide_rate_service['state'][i]
    y = suicide_rate_service['2018'][i]
    plt.scatter(x, y, marker='o', color='blue')
    plt.text(x+0.3, y+0.3, type, fontsize=5, wrap=True)


plt.show()

# %%
x_suicide = suicide_rate_service['RATE']
y_suicide = suicide_rate_service['2017']

for i,type in enumerate(suicide_rate_service['state']):
    x = x_suicide[i]
    y = y_suicide[i]
    plt.scatter(x, y, marker='o', color='cornflowerblue', edgecolors='darkblue')
    
    if (x < 10) or (x > 25) or (y < 38) or (y> 80):
        plt.text(x+0.3, y+0.3, type, fontsize=8, wrap=True)

z = np.polyfit(x_suicide, y_suicide, 1)
p = np.poly1d(z)
plt.plot(x_suicide,p(x_suicide),"r--", color = 'dimgray')

plt.xlabel('Suicide Death Rate')
plt.ylabel('% Of MH Facilities Offering Suicide Prevention')
plt.title("2017 Suicide Death Rate vs % of MH Facilities Offering Suicide Prevention Services by State", wrap=True)
plt.grid()
plt.savefig("Images/suicide_rate_service.png")

plt.show()

# %%
x_suicide_p = suicide_rate_payment['RATE']
y_suicide_p = suicide_rate_payment['2017']

for i,type in enumerate(suicide_rate_payment['state']):
    x = x_suicide_p[i]
    y = y_suicide_p[i]
    plt.scatter(x, y, marker='o', color='cornflowerblue', edgecolors='darkblue')
    
    if (x < 10) or (x > 25) or (y < 38):
        plt.text(x+0.3, y+0.3, type, fontsize=8, wrap=True)

z = np.polyfit(x_suicide_p, y_suicide_p, 1)
p = np.poly1d(z)
plt.plot(x_suicide_p,p(x_suicide_p),"r--", color = 'dimgray')

plt.xlabel('Suicide Death Rate')
plt.ylabel('% Of MH Facilities Offering Payment Assistance')
plt.title("2017 Suicide Death Rate vs % of MH Facilities Offering Payment Assistance by State", wrap=True)
plt.grid()
plt.savefig("Images/suicide_rate_payment.png")

plt.show()

# %%
lang_plot = mh_suicide_2017.sort_values('RATE', ascending=True).plot(kind="bar", x = "state", y = "RATE")
lang_plot.plot(figsize=(8, 6))
plt.title('2017 Suicide Death Rate by State')
plt.xlabel('State')
plt.ylabel( 'Suicide Death Rate')
plt.tight_layout()
plt.savefig("Images/suicide_rate.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mh_suicide_2017.loc[mh_suicide_2017['RATE']>20]
# Out:
#     Unnamed: 0          state  RATE
# 1            1         Alaska  27.0
# 3            3       Arkansas  20.8
# 5            5       Colorado  20.3
# 11          11          Idaho  23.2
# 25          25        Montana  28.9
# 27          27         Nevada  20.3
# 30          30     New Mexico  23.3
# 33          33   North Dakota  20.1
# 40          40   South Dakota  22.5
# 43          43           Utah  22.7
# 47          47  West Virginia  21.1
# 49          49        Wyoming  26.9

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(mh_suicide_programs.mean(), label = "Suicide Prevention Program")
plt.xlabel('Year')
plt.ylabel('% of MH Facilities offering programs')
plt.title("U.S. Mental Health Facility Programs", wrap=True)

plt.grid()
ax.plot(mh_payassist_trends.mean(), label = "Payment Assistance Program")

ax.plot(mh_cosubstance_programs.mean(), label = "Substance Abuse Treatment")
ax.plot(mh_lgbt_trends.mean(), label = "LGBT Program")


ax.plot(mh_veteran_programs.mean(), label = "Veteran Program")
ax.plot(mh_housing_programs.mean(), label = "Housing Program")
ax.plot(mh_education_programs.mean(), label = "Education Program")

ax.legend()
plt.savefig("Images/mh_programs_byyear.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
